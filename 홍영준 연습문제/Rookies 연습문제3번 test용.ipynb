# %% [markdown]
# ### ✅ 1단계: 문서 분할 설정

# %%
#pip install -U langchain-openai

# %%
import os
from dotenv import load_dotenv

load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
print(OPENAI_API_KEY[:2])
# Out:
# sk

# %% [markdown]
# ### ✅ 2단계: 임베딩 모델 설정

# %%
from langchain_openai import OpenAIEmbeddings
import numpy as np

# OpenAI의 "text-embedding-3-small" 모델을 사용하여 임베딩 객체 생성
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")
print("✅ 임베딩 객체가 성공적으로 생성되었습니다.")
# Out:
# ✅ 임베딩 객체가 성공적으로 생성되었습니다.

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

print("[텍스트 분할기 설정]")
print("="*50)

# 텍스트 분할 설정 (chunk_size, chunk_overlap 증가로 속도 개선 의도)
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=3500,      # 법률 사례는 1200~1800자 권장하지만 속도 위해 늘림
    chunk_overlap=300,    # 맥락 보존을 위해 200~400자 설정 유지
    separators=[
        "\n【사건개요】", "\n【쟁점사항】", "\n【처리경위】", "\n【처리결과】",
        "\n■", "\n\n", "\n", ".", " ", ""
    ]
)

# 설정 값 출력
print(f"✅ 청크 크기(chunk_size): {text_splitter._chunk_size}자")
print(f"✅ 오버랩(chunk_overlap): {text_splitter._chunk_overlap}자")
print(f"✅ 분할 구분자(separators): {text_splitter._separators[:4]}... (총 {len(text_splitter._separators)}개)")
print("="*50)

# 테스트 문서 분할 (가상의 예시 문서 - 길게 이어붙여서 청크 분할 효과 확인)
sample_text = """
【사건개요】 
게임사 A는 2023년 5월 출시한 모바일 게임 내 프리미엄 아이템 확률 표시를 누락하여 이용자 1,200명이 집단 분쟁 제기.

【쟁점사항】
1. 확률 표시 의무 위반 여부
2. 피해 금액 산정 기준
3. 환불 범위 설정 문제

【처리결과】
게임사는 전체 이용자에게 아이템 비용 환불 및 10% 추가 보상 제공.

【사건개요】 
또 다른 게임사 B는 2024년 1월 출시한 게임에서 미성년자 결제 관련 분쟁이 발생함.

【쟁점사항】
1. 부모 동의 없는 결제 문제
2. 환불 정책의 적절성
3. 게임사 책임 범위

【처리경위】
게임사는 피해자들에게 개별 연락하여 환불 진행 중이며, 법적 조치도 검토함.

【처리결과】
일부 환불 완료, 추가 보상 여부는 추후 결정 예정.
"""

print("\n[테스트 분할 실행]")
print("="*50)
try:
    chunks = text_splitter.split_text(sample_text)
    print(f"✅ 분할 완료 (생성된 청크 수: {len(chunks)}개)")
    print("\n[첫 번째 청크 내용]")
    print("-"*30)
    print(chunks[0])
    print("-"*30)
    if len(chunks) > 1:
        print("\n[두 번째 청크 내용]")
        print("-"*30)
        print(chunks[1])
        print("-"*30)
except Exception as e:
    print(f"❌ 분할 실패: {str(e)}")
# Out:
# [텍스트 분할기 설정]
# ==================================================
# ✅ 청크 크기(chunk_size): 3500자
# ✅ 오버랩(chunk_overlap): 300자
# ✅ 분할 구분자(separators): ['\n【사건개요】', '\n【쟁점사항】', '\n【처리경위】', '\n【처리결과】']... (총 10개)
# ==================================================
#
# [테스트 분할 실행]
# ==================================================
# ✅ 분할 완료 (생성된 청크 수: 1개)
#
# [첫 번째 청크 내용]
# ------------------------------
# 【사건개요】
# 게임사 A는 2023년 5월 출시한 모바일 게임 내 프리미엄 아이템 확률 표시를 누락하여 이용자 1,200명이 집단 분쟁 제기.
#
# 【쟁점사항】
# 1. 확률 표시 의무 위반 여부
# 2. 피해 금액 산정 기준
# 3. 환불 범위 설정 문제
#
# 【처리결과】
# 게임사는 전체 이용자에게 아이템 비용 환불 및 10% 추가 보상 제공.
#
# 【사건개요】
# 또 다른 게임사 B는 2024년 1월 출시한 게임에서 미성년자 결제 관련 분쟁이 발생함.
#
# 【쟁점사항】
# 1. 부모 동의 없는 결제 문제
# 2. 환불 정책의 적절성
# 3. 게임사 책임 범위
#
# 【처리경위】
# 게임사는 피해자들에게 개별 연락하여 환불 진행 중이며, 법적 조치도 검토함.
#
# 【처리결과】
# 일부 환불 완료, 추가 보상 여부는 추후 결정 예정.
# ------------------------------

# %%
from langchain.document_loaders import PyPDFLoader
from langchain.vectorstores import FAISS

# PDF 파일 경로
pdf_path = "C:/mylangchain/langchain_basic/data/콘텐츠분쟁해결_사례.pdf"

# 1. 로딩
loader = PyPDFLoader(pdf_path)
pages = loader.load()

# 2. 분할
documents = text_splitter.split_documents(pages)

# 3. 벡터 임베딩 & 저장소 생성
vectorstore = FAISS.from_documents(documents, embedding=embeddings)

# 4. 검색기 생성
retriever = vectorstore.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 5}
)

print(f"총 분할 문서 수: {len(documents)}개")
# Out:
# 총 분할 문서 수: 102개

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="gpt-4o",
    temperature=0.2,
    max_tokens=2000
)

print("✅ ChatOpenAI LLM(gpt-4o) 객체 생성 완료")
# Out:
# ✅ ChatOpenAI LLM(gpt-4o) 객체 생성 완료

# %%
from langchain.prompts import PromptTemplate

# 프롬프트 템플릿 문자열
prompt_template = """
당신은 콘텐츠 분야 전문 법률 자문사입니다. 
아래 분쟁조정 사례들을 바탕으로 정확하고 전문적인 법률 조언을 제공해주세요.

관련 분쟁사례:
{context}

상담 내용: {question}

답변 가이드라인:
1. 제시된 사례들을 근거로 답변하세요
2. 관련 법령이나 조항이 있다면 명시하세요
3. 실무적 해결방안을 단계별로 제시하세요
4. 비슷한 사례의 처리경위와 결과를 참고하여 설명하세요
5. 사례에 없는 내용은 "제시된 사례집에서는 확인할 수 없습니다"라고 명시하세요

전문 법률 조언:
"""

# 템플릿 객체 생성
prompt = PromptTemplate(
    input_variables=["context", "question"],
    template=prompt_template
)

print("✅ 프롬프트 템플릿 객체 생성 완료")
# Out:
# ✅ 프롬프트 템플릿 객체 생성 완료

# %%
from langchain.chains import RetrievalQA

qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=retriever,
    chain_type_kwargs={"prompt": prompt},
    return_source_documents=True
)

print("QA 체인 생성 완료 ✅")
# Out:
# QA 체인 생성 완료 ✅

# %%
test_questions = [
    "온라인 게임에서 시스템 오류로 아이템이 사라졌는데, 게임회사가 복구를 거부하고 있습니다. 어떻게 해결할 수 있나요?",
    "인터넷 강의를 중도 해지하려고 하는데 과도한 위약금을 요구받고 있습니다. 정당한가요?",
    "무료체험 후 자동으로 유료전환되어 요금이 청구되었습니다. 환불 가능한가요?",
    "미성년자가 부모 동의 없이 게임 아이템을 구매했습니다. 환불받을 수 있는 방법이 있나요?",
    "온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶습니다. 가능한가요?"
]

for i, q in enumerate(test_questions, 1):
    print(f"\n\n========================= 질문 {i} =========================")
    print(f"❓ 질문: {q}")

    # QA 체인 실행
    result = qa_chain.invoke({"query": q})

    # 답변 출력 (한 줄씩)
    print("\n✅ 생성된 답변:")
    for line in result["result"].split('\n'):
        print(line.strip())

    # 참조된 문서 정보 출력 (한 줄씩)
    print("\n📚 참고 문서 목록:")
    for j, doc in enumerate(result["source_documents"], 1):
        source = doc.metadata.get("source", "출처 정보 없음")
        preview = doc.page_content[:200].replace('\n', ' ').strip()
        print(f"  {j}. 문서 출처: {source}")
        print(f"     - 내용 미리보기: {preview} ...")
# Out:
# ========================= 질문 1 =========================
# ❓ 질문: 온라인 게임에서 시스템 오류로 아이템이 사라졌는데, 게임회사가 복구를 거부하고 있습니다. 어떻게 해결할 수 있나요?
#
# ✅ 생성된 답변:
# 온라인 게임에서 시스템 오류로 인해 아이템이 사라진 경우, 게임회사가 복구를 거부하는 상황에 대한 법률 조언을 다음과 같이 제공합니다.
#
# 1. **사례 분석**:
# - 제시된 사례들에서 공통적으로 나타나는 문제는 시스템 오류로 인한 아이템 소실에 대한 복구 요청입니다. 특히, 사례 1-가-1(2006)과 1-가-1(2009)에서는 시스템 오류로 인한 아이템 소실에 대해 게임회사가 복구를 거부한 상황이 있습니다.
# - 2006년 사례에서는 계정 명의자가 아닌 경우 복구가 불가하다는 게임사의 약관에 따라 복구가 거부되었습니다.
# - 2009년 사례에서는 시스템 오류가 아닌 사용자 측의 문제일 가능성이 있다는 이유로 복구가 거부되었습니다.
#
# 2. **관련 법령 및 조항**:
# - 약관의 규제에 관한 법률 제11조는 고객의 권익 보호를 규정하고 있으며, 소비자분쟁해결기준(공정위고시 제2010-1호)에서는 전자상거래 등에서의 소비자 보호에 관한 기준을 제시하고 있습니다.
#
# 3. **실무적 해결방안**:
# - **1단계: 증거 수집**: 시스템 오류로 인한 아이템 소실을 증명할 수 있는 증거(스크린샷, 로그 기록 등)를 수집합니다.
# - **2단계: 게임사와의 협의**: 수집한 증거를 바탕으로 게임사에 다시 복구 요청을 하며, 게임사의 약관 및 운영정책을 검토하여 복구 가능성을 확인합니다.
# - **3단계: 소비자 보호 기관에 문의**: 게임사가 복구를 거부할 경우, 한국소비자원이나 전자거래분쟁조정위원회에 중재를 요청할 수 있습니다.
# - **4단계: 법적 조치 고려**: 위의 단계들이 모두 실패할 경우, 법적 조치를 고려할 수 있으며, 이때는 변호사와 상담하여 소송 가능성을 검토합니다.
#
# 4. **비슷한 사례의 처리경위와 결과**:
# - 2006년 사례에서는 계정 명의자가 아닌 경우 복구가 불가하다는 게임사의 약관에 따라 복구가 거부되었습니다.
# - 2009년 사례에서는 시스템 오류가 아닌 사용자 측의 문제일 가능성이 있다는 이유로 복구가 거부되었습니다.
#
# 5. **추가 정보**:
# - 제시된 사례집에서는 시스템 오류로 인한 아이템 소실에 대해 게임사가 복구를 수용한 사례는 확인할 수 없습니다.
#
# 이러한 조언을 바탕으로 문제 해결을 위한 적절한 조치를 취하시기 바랍니다.
#
# 📚 참고 문서 목록:
#   1. 문서 출처: C:/mylangchain/langchain_basic/data/콘텐츠분쟁해결_사례.pdf
#      - 내용 미리보기: 1. 게임 3 게임1 ■ 1-가-1) 한국소비자원 조정전 상담사례2006_시스템 오류로 소멸된 아이템 복구 요구【사건개요】신청인은 피신청인이 제공하는 온라인게임서비스를 이용하던 중 시스템 오류로 120,000원 상당의 아이템이 소멸되었고, 이에 피신청인에게 수차례 이의제기하였으나 사과 공지문만 안내 되고 아이템이 복구 되지 않았다. 피신청인이 정상적으로 거 ...
#   2. 문서 출처: C:/mylangchain/langchain_basic/data/콘텐츠분쟁해결_사례.pdf
#      - 내용 미리보기: 1. 게임 23 ■ 1-가-1) 한국소비자원 조정전 상담사례2009_시스템 오류로 인한 손실 아이템 복구 요구【사건개요】신청인은 2009. 9. 4 피신청인 프로그램 업데이트 후 2009. 9. 5 온라인게임 서비스를 이용하다 렉(시스템오류)발생으로 며칠간 오류현상이 반복되더니 신청인의 게임머니 1,000억 가량이 소실된 것을 확인 한 뒤, 피신청인 시스템 ...
#   3. 문서 출처: C:/mylangchain/langchain_basic/data/콘텐츠분쟁해결_사례.pdf
#      - 내용 미리보기: 1. 게임 25 ■ 1-가-1) 한국소비자원 조정전 상담사례2009_해킹으로 손실된 아이템 복구 요청【사건개요】피청구인이 제공하는 게임서비스 가입자로서 2009. 5. 10 잠시 게임에 접속했다가 4시간 후 재접속해보니 누군가 자신의 게임에 접속하여 이용하고 있는 상태임을 확인하고, 이에 계정이 해킹된 사실을 감지하고 즉시 게임사에 해킹신고를 한 뒤 새벽에 ...
#   4. 문서 출처: C:/mylangchain/langchain_basic/data/콘텐츠분쟁해결_사례.pdf
#      - 내용 미리보기: 1. 게임 39 ■ 1-나 전자거래분쟁조정위원회 조정결정례2006_게임계정 영구 압류조치 해제 청구【사건개요】신청인은 피신청인이 운영하는 게임 사이트에서 게임을 하던 중 아이템을 구입하던 과정에서 아이템을 구입하면 튕기면서 아이템이 구매되지만 사이버머니는 그대로 있는 상황이 반복되는 현상을 겪었고, 어느 정도 시간이 지난 후 운영자 점검 화면이 뜨는 것을 ...
#   5. 문서 출처: C:/mylangchain/langchain_basic/data/콘텐츠분쟁해결_사례.pdf
#      - 내용 미리보기: 차  례      콘텐츠분쟁조정 법리 연구 제2부 - 타 분쟁조정사례 조사 -타 분쟁조정 위원회 콘텐츠 분쟁해결 사례이지현(드림와이즈) 1. 게임····································································································1가. 한국소비자원1) 조정전 상담 ...
#
#
# ========================= 질문 2 =========================
# ❓ 질문: 인터넷 강의를 중도 해지하려고 하는데 과도한 위약금을 요구받고 있습니다. 정당한가요?
#
# ✅ 생성된 답변:
# 전문 법률 조언:
#
# 1. **사례 근거 답변**:
# 제시된 사례들에서 공통적으로 다루어지는 문제는 중도 해지 시 과도한 위약금 청구입니다. 여러 사례에서 피신청인이 위약금 및 기타 비용을 과도하게 청구하여 분쟁이 발생하였으며, 조정 과정에서 위약금의 적정성 여부가 주요 쟁점으로 다루어졌습니다.
#
# 2. **관련 법령 및 조항**:
# - **방문판매 등에 관한 법률 제29조**: 계약의 해지에 관한 규정으로, 계약 해지 시 위약금의 적정성을 판단하는 기준이 됩니다.
# - **소비자기본법에 따른 소비자분쟁해결기준**: 공정거래위원회 고시로, 인터넷 콘텐츠업에 대한 분쟁 해결 기준을 제시합니다.
# - **약관의 규제에 관한 법률 제9조**: 계약의 해제 및 해지에 관한 규정으로, 약관에 의한 계약 해지 제한의 적정성을 판단하는 데 사용됩니다.
#
# 3. **실무적 해결방안**:
# - **계약서 및 약관 검토**: 먼저, 계약서와 약관을 면밀히 검토하여 위약금 및 기타 비용의 부과 근거가 명확히 명시되어 있는지 확인합니다.
# - **위약금 적정성 판단**: 위약금이 과도한지 여부를 판단하기 위해, 소비자분쟁해결기준 및 관련 법령을 참고하여 위약금이 실제 손실을 현저히 초과하는지 검토합니다.
# - **조정 신청**: 위약금이 과도하다고 판단될 경우, 한국소비자원 또는 전자거래분쟁조정위원회에 조정을 신청하여 중재를 요청할 수 있습니다.
# - **협상 및 합의**: 조정 과정에서 피신청인과의 협상을 통해 합리적인 수준의 위약금으로 합의할 수 있도록 노력합니다.
#
# 4. **비슷한 사례의 처리경위 및 결과**:
# - 2007년 온라인통신교육서비스 대금 환급 요구 사례에서는 피신청인이 과도한 위약금을 청구하였으나, 계약서에 명시된 금액과 실제 손실을 기준으로 조정이 이루어졌습니다.
# - 2009년 인터넷 학습사이트 가입 해지 사례에서는 피신청인이 환불 불가 약관을 주장하였으나, 약관의 적정성 여부가 쟁점이 되어 조정이 진행되었습니다.
#
# 5. **사례에 없는 내용**:
# 제시된 사례집에서는 특정한 금액의 위약금이 과도한지 여부에 대한 구체적인 기준이나 판례는 확인할 수 없습니다. 각 사례의 구체적인 계약 내용과 상황에 따라 다르게 판단될 수 있습니다.
#
# 이러한 조언을 바탕으로, 계약 해지 및 위약금 문제를 해결하기 위해서는 계약서와 약관을 철저히 검토하고, 필요한 경우 조정 기관을 통해 중재를 요청하는 것이 중요합니다.
#
# 📚 참고 문서 목록:
#   1. 문서 출처: C:/mylangchain/langchain_basic/data/콘텐츠분쟁해결_사례.pdf
#      - 내용 미리보기: 차  례      콘텐츠분쟁조정 법리 연구 제2부 - 타 분쟁조정사례 조사 - 2009_사용하지 못한 게임머니의 환급 요구·····················································2 72008_인터넷 게임 계정 영구이용 제한조치 취소 요구····································2 82) 조정결정 ...
#   2. 문서 출처: C:/mylangchain/langchain_basic/data/콘텐츠분쟁해결_사례.pdf
#      - 내용 미리보기: 2. 이러닝 57 ■ 2-가 한국소비자원 조정결정례2007_인터넷교육서비스 중도해지 요구【사건개요】청구인은 2006. 2. 8. 피청구인이 운영하는 인터넷교육서비스를 청구인의 자녀가 1년간 이용하기로 약정하고 1,740,000원을 지급하였으나 서비스 내용에 불만이 있어 같은 해 5. 3. 계약해지를 요청하고 적정 금액의 환급을 요구하였다. 피청구인은 청구인 ...
#   3. 문서 출처: C:/mylangchain/langchain_basic/data/콘텐츠분쟁해결_사례.pdf
#      - 내용 미리보기: 2. 이러닝 55 ■ 2-가 한국소비자원 조정결정례2007_온라인통신교육서비스 대금 환급 요구2【사건개요】청구인은 2006. 10. 30. 자신의 자녀가 컴퓨터통신교육서비스를 1년간 이용하기로 피청구인과 계약하고 이용대금 1,100,000원을 지급하였으나 청구인의 사정으로 이용할 수 없게 되어 같은 해 12. 28. 피청구인에게 계약해지를 통보하였으나, 피 ...
#   4. 문서 출처: C:/mylangchain/langchain_basic/data/콘텐츠분쟁해결_사례.pdf
#      - 내용 미리보기: 2. 이러닝 63 ■ 2-가 한국소비자원 조정결정례2009_인터넷 학습사이트 가입 해지에 따른 대금 환급 요구【사건개요】신청인은 2009. 3. 16. 자녀 2인의 교육을 위해 피신청인 인터넷 학습사이트에 회원으로 가입하고 2009.3.16 ∼ 2010.9.16까지 1인당 1,800건까지의 자료 다운로드 횟수를 내용으로 한하는 계약을 체 결한  뒤  425 ...
#   5. 문서 출처: C:/mylangchain/langchain_basic/data/콘텐츠분쟁해결_사례.pdf
#      - 내용 미리보기: 콘텐츠분쟁조정 법리 연구 2부 - 타 분쟁조정사례 조사 - 82 ■ 2-다 전자거래분쟁조정위원회 조정결정례2008_이러닝 서비스 이용료 반환 신청【사건개요】신청인은 2007. 8. 24. 자녀를 위하여 이러닝 서비스 제공업체인 피신청인과 36개월 이용 계약(30개월 유료+6개월 서비스 특약)을 체결하면서 2,880,000원(월 96,000원*30개월)을 지 ...
#
#
# ========================= 질문 3 =========================
# ❓ 질문: 무료체험 후 자동으로 유료전환되어 요금이 청구되었습니다. 환불 가능한가요?
#
# ✅ 생성된 답변:
# 무료체험 후 자동으로 유료전환되어 요금이 청구된 경우, 환불 가능 여부에 대한 법률 조언은 다음과 같습니다.
#
# 1. **관련 법령 및 조항**:
# - **약관의 규제에 관한 법률 제3조**: 약관의 작성 및 설명의무에 따라, 사업자는 계약의 중요한 내용을 소비자가 쉽게 이해할 수 있도록 명확히 설명해야 합니다.
# - **소비자기본법**: 소비자 보호를 위한 법률로, 소비자가 오인할 수 있는 광고나 약관에 대해 시정 조치를 요구할 수 있습니다.
#
# 2. **사례 분석**:
# - **사례 3-가**: 신청인은 무료 이벤트 참여 후 자동 유료 전환에 대해 충분히 고지받지 못했다고 주장하였으나, 사업자가 여러 차례 유료 전환에 대해 고지한 점과 신청인이 4개월간 이의 없이 대금을 결제한 점을 고려하여 사업자의 책임을 50%로 제한하였습니다.
# - **사례 3-나**: 무료 광고 후 유료 서비스로 전환된 경우, 소비자가 충분히 인지하기 어려운 고지 방식이 문제로 지적되었습니다. 이는 소비자 보호 관련 법규 위반 소지가 있어 시정 대상이 될 수 있습니다.
#
# 3. **실무적 해결방안**:
# - **1단계: 계약 내용 확인**: 회원 가입 시 제공된 약관 및 이벤트 고지 내용을 확인하여 유료 전환에 대한 고지가 있었는지 확인합니다.
# - **2단계: 사업자와의 협상**: 사업자에게 고지의 불충분함을 근거로 환불을 요청합니다. 이때, 사례 3-가와 같이 사업자의 책임을 일부 인정받을 수 있습니다.
# - **3단계: 분쟁 조정 신청**: 협상이 원활하지 않을 경우, 전자거래분쟁조정위원회나 한국소비자원에 분쟁 조정을 신청할 수 있습니다.
# - **4단계: 법적 조치 검토**: 조정이 실패할 경우, 법적 조치를 검토할 수 있으며, 이때는 관련 법령에 따라 사업자의 설명의무 위반을 주장할 수 있습니다.
#
# 4. **비슷한 사례의 처리경위와 결과**:
# - 사례 3-가에서는 사업자가 유료 전환 고지를 했으나, 소비자가 이를 충분히 인지하지 못한 점을 고려하여 50% 환불이 결정되었습니다.
# - 사례 3-나에서는 고지 방식의 불명확함이 문제로 지적되었으며, 이는 소비자 보호 관련 법규 위반으로 시정 대상이 될 수 있음을 보여줍니다.
#
# 5. **추가 정보**:
# - 제시된 사례집에서는 확인할 수 없는 내용이 있을 수 있습니다. 구체적인 계약 내용이나 고지 방식에 대한 추가적인 정보가 필요할 수 있습니다.
#
# 이러한 조언을 바탕으로, 귀하의 상황에 맞는 적절한 조치를 취하시기 바랍니다.
#
# 📚 참고 문서 목록:
#   1. 문서 출처: C:/mylangchain/langchain_basic/data/콘텐츠분쟁해결_사례.pdf
#      - 내용 미리보기: 3. 기타(웹) 95 ■ 3-가 한국소비자원 조정결정례2010_무료 이벤트 후 자동 소액 결제 요금 환급요구【사건개요】신청인은 2008. 12. 29. 피신청인 1이 운영하는 음악 다운로드 사이트 '003'의 무료이벤트(이벤트명 : '003' 7일 무료체험이벤트)에 참여하여 회원가입을 하였다. 그러나 2008. 1.부터 본인동의 없이 유료 회원으로 자동 가 ...
#   2. 문서 출처: C:/mylangchain/langchain_basic/data/콘텐츠분쟁해결_사례.pdf
#      - 내용 미리보기: 3. 기타(웹) 97 ■ 3-나 전자거래분쟁조정위원회 조정전합의 사례2006_무료 광고 후 서비스 이용요금 청구【사건개요】신청인은 한 사이버몰에서 무료 핸드폰 이용권 이벤트에 참여하던 중 핸드폰 번호와 주민번호를 입력하도록 요구받고 이에 응하자 휴대폰으로 요금결제 메시지가 수신되었다. 신청인은 위 문자가 회사측에서 결제하여주는 무료 이용요금으로 생각하였으나 ...
#   3. 문서 출처: C:/mylangchain/langchain_basic/data/콘텐츠분쟁해결_사례.pdf
#      - 내용 미리보기: 2. 이러닝 81 ■ 2-다 전자거래분쟁조정위원회 조정결정례2006_동영상 강의 신청취소에 대한 환불지연【사건개요】신청인은 피신청인의 사이트에서 360,000원의 비용으로 동영상 강의를 신청한 후 바로 당일 취소하게 되었다. 하지만 피신청인 측에서는 내부규정이라는 명분으로 한 달이 지나야 결제대금을 환급해줄 수 있다고 하면서 환불을 지연시켰다.이에 신청인은 ...
#   4. 문서 출처: C:/mylangchain/langchain_basic/data/콘텐츠분쟁해결_사례.pdf
#      - 내용 미리보기: 2. 이러닝 89 상기 내용을 살펴보면, 신청인은 청약철회 기간을 지났으므로 위 계약의 청약을 철회할 수는 없는 것으로 보인다. 피신청인은 위 계약에 따라 정해진 기간 내에 신청인이 접근하여 온라인 강좌를 수강할 수 있는 여건을 제공하는 등 피신청인의 계약상 의무는 이행된 것으로 보이며, 피신청인의 약관에 따른 환불기준에 의하더라도 신청인은 환불에 필요한 ...
#   5. 문서 출처: C:/mylangchain/langchain_basic/data/콘텐츠분쟁해결_사례.pdf
#      - 내용 미리보기: 콘텐츠분쟁조정 법리 연구 2부 - 타 분쟁조정사례 조사 - 96 받는 것과는 달리 무료 이벤트 참여를 위한 회원 가입 시 인증번호를 부여받게 되어있다는 점, 계약 해지를 통지하지 않아 자동 소액 결제 전환 시에도 신청인에게 유료로 전환된다는 사실이 고지되지 않았다는 점으로 미루어 신청인에게 계약해지 등과 관련된 계약 내용을 충분히 고지하였다고 보기는 어렵다 ...
#
#
# ========================= 질문 4 =========================
# ❓ 질문: 미성년자가 부모 동의 없이 게임 아이템을 구매했습니다. 환불받을 수 있는 방법이 있나요?
#
# ✅ 생성된 답변:
# 전문 법률 조언:
#
# 1. **관련 법령 및 조항**:
# - **민법 제5조**: 미성년자의 능력에 관한 규정으로, 미성년자는 법정대리인의 동의 없이 단독으로 법률행위를 할 수 없습니다.
# - **민법 제741조**: 부당이득의 내용으로, 법률상 원인 없이 타인의 재산이나 이익을 얻은 경우 이를 반환해야 합니다.
# - **민법 제753조 및 제755조**: 미성년자의 책임능력 및 책임무능력자의 감독자의 책임에 관한 규정입니다.
# - **민법 제17조**: 무능력자의 사술에 관한 규정으로, 미성년자가 자신의 능력을 속여 계약을 체결한 경우 취소권이 제한될 수 있습니다.
#
# 2. **사례 분석**:
# - **사례 1**: 미성년자가 타인의 명의를 도용하여 결제한 경우, 이는 법정대리인의 동의 없이 이루어진 계약으로 볼 수 있으며, 부당이득 반환의 대상이 될 수 있습니다. 그러나 피신청인이 실명확인 절차를 거쳤다는 점에서 환불이 어려울 수 있습니다.
# - **사례 2**: 미성년자가 부모의 신용카드를 부정 사용한 경우, 피신청인이 미성년자의 사술에 의해 계약이 체결된 것으로 판단하여 취소권이 제한될 수 있습니다. 다만, 구입한 게임머니를 반환하는 경우 환불이 가능할 수 있습니다.
# - **사례 3**: 미성년자가 타인의 사술에 의해 결제한 경우, 피신청인이 이를 인정하고 환급 조치를 취한 사례입니다.
#
# 3. **실무적 해결방안**:
# - **1단계**: 결제 내역 및 계약 체결 과정을 확인하여 미성년자의 사술 여부 및 법정대리인의 동의 여부를 검토합니다.
# - **2단계**: 피신청인(게임사)와의 협의를 통해 환불 가능성을 타진합니다. 특히, 구입한 아이템이나 게임머니를 반환할 수 있는지 확인합니다.
# - **3단계**: 피신청인이 협조하지 않을 경우, 전자거래분쟁조정위원회나 한국소비자원에 분쟁조정을 신청하여 해결을 모색합니다.
# - **4단계**: 법적 조치를 고려할 경우, 민법상의 부당이득 반환 청구나 계약 취소를 근거로 소송을 제기할 수 있습니다.
#
# 4. **비슷한 사례의 처리경위와 결과**:
# - **사례 1**에서는 미성년자의 명의 도용으로 인한 결제에 대해 환불이 어려웠으나, **사례 3**에서는 타인의 사술에 의해 결제된 금액이 환급되었습니다. 이는 피신청인의 대응 및 사술 여부에 따라 결과가 달라질 수 있음을 보여줍니다.
#
# 5. **추가 정보**:
# - 제시된 사례집에서는 미성년자가 부모 동의 없이 게임 아이템을 구매한 경우의 환불 절차에 대한 구체적인 정보는 확인할 수 없습니다. 그러나 위의 법령 및 사례를 근거로 환불 가능성을 검토할 수 있습니다.
#
# 이와 같은 절차를 통해 미성년자의 부당한 결제에 대한 환불을 받을 수 있는 가능성을 높일 수 있습니다. 각 사례의 구체적인 상황에 따라 결과가 달라질 수 있으므로, 필요한 경우 전문 법률가의 조언을 받는 것이 좋습니다.
#
# 📚 참고 문서 목록:
#   1. 문서 출처: C:/mylangchain/langchain_basic/data/콘텐츠분쟁해결_사례.pdf
#      - 내용 미리보기: 1. 게임 45 ■ 1-나 전자거래분쟁조정위원회 조정결정례2008_부당결제대금 반환 청구【사건개요】신청인의 자녀는 2004. 4. 22. 피신청인이 운영하는 게임 사이트에 가명으로 타인(성인)의 주민번호를 이용하여 회원가입을 한 뒤 2007. 9. ∼ 2007.12. 까지 해당게임을 이용하면서 아이템 구입을 위해 총 18회에 걸쳐 284,900원을 집전화로 ...
#   2. 문서 출처: C:/mylangchain/langchain_basic/data/콘텐츠분쟁해결_사례.pdf
#      - 내용 미리보기: 1. 게임 47 신청인의 미성년 아들이 신청인의 이름을 도용하여 피신청인사 사이트에 회원 가입 후 2008. 9. 23.부터 같은 해 9. 25.까지 주(A)사의 대표적 게임인 0000게임 머니를 3,709,480원 어치를 구매하였다. 이에 피 신청인은 미성년자 신용카드 부정사용을 이유로 신용카드 결제 취소를 요청했고 이에 신청인과 피신청인 사이에 사실관계 ...
#   3. 문서 출처: C:/mylangchain/langchain_basic/data/콘텐츠분쟁해결_사례.pdf
#      - 내용 미리보기: 콘텐츠분쟁조정 법리 연구 2부 - 타 분쟁조정사례 조사 - 50 본건은 2008. 9. 22. 신청인의 미성년 아들이 신청인의 이름을 도용하여 피신청인사 사이트에 회원 가입한 후 2008년 9월 23일부터 같은 해 9월 25일까지 (주)A사의 대표적 게임인 ○○○게임 머니를 3,709,480원어치를 구매한 사안으로서, 2008년 9월 23일자 구매신청서 가 ...
#   4. 문서 출처: C:/mylangchain/langchain_basic/data/콘텐츠분쟁해결_사례.pdf
#      - 내용 미리보기: 콘텐츠분쟁조정 법리 연구 2부 - 타 분쟁조정사례 조사 - 48  - 피신청인  ㆍ 피신청인은 구매당시 구매자에게 전화를 하였을 당시 전화를 받은 자는 자신을 24세의 남성으로 카드명의자의 아들이라 소개하며 문제가 없음을 몇 번이나 이야기 하였고, 구매 금액이 과다하여 24.∼25. 통화확인 시에도 같은 주장을 하여 음성 확인 시 성년이라 짐작하여 온라인 ...
#   5. 문서 출처: C:/mylangchain/langchain_basic/data/콘텐츠분쟁해결_사례.pdf
#      - 내용 미리보기: 1. 게임 9 ■ 1-가-1) 한국소비자원 조정전 상담사례2007_미성년자가 타인의 사술에 의해 부당하게 결제한 요금 환급 요구【사건개요】신청인은 2007. 1. 17. 집 전화 요금 내역을 확인하던 중 사용하지 않은 정보이용료 66,000원이 부과된 것을 인지하고 확인한 바, 9세인 아들이 피신청인의 게임 중 신원 미상자가 선물을 준다며 전화를 걸도록 유 ...
#
#
# ========================= 질문 5 =========================
# ❓ 질문: 온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶습니다. 가능한가요?
#
# ✅ 생성된 답변:
# 온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고자 하는 경우, 다음과 같은 법률적 조언을 드릴 수 있습니다.
#
# 1. **계약 해지 가능성**:
# - 제시된 사례들에 따르면, 온라인 교육 서비스와 같은 계속적 거래 계약은 「방문판매 등에 관한 법률」 제29조에 따라 언제든지 해지할 수 있습니다. 따라서, 광고와 다르게 서비스가 제공되었다면 계약 해지가 가능합니다.
#
# 2. **관련 법령**:
# - 「방문판매 등에 관한 법률」 제30조는 계약 해지 시 소비자에게 해지로 인해 발생하는 손실을 현저하게 초과하는 위약금을 청구할 수 없다고 규정하고 있습니다.
# - 소비자기본법에 따른 소비자분쟁해결기준(공정위고시, 인터넷콘텐츠업)도 참고할 수 있습니다.
#
# 3. **실무적 해결방안**:
# - **1단계**: 계약 해지 의사를 명확히 표시하세요. 이는 서면으로 하는 것이 좋습니다.
# - **2단계**: 서비스가 광고와 다르게 제공되었음을 입증할 수 있는 자료(예: 광고 내용, 실제 서비스 내용)를 준비하세요.
# - **3단계**: 환급을 요구할 때는 소비자분쟁해결기준에 따라 해지일까지의 이용일수에 해당하는 금액과 총이용금액의 10%를 공제한 후 환급을 요구할 수 있습니다.
# - **4단계**: 사업자가 환급을 거부하거나 과도한 위약금을 청구할 경우, 한국소비자원이나 전자거래분쟁조정위원회에 조정을 신청할 수 있습니다.
#
# 4. **비슷한 사례의 처리경위와 결과**:
# - 2009년 사례에서는 계약 해지 시 총 이용요금의 2/3를 공제하겠다는 사업자의 주장이 받아들여지지 않았습니다. 소비자에게 해지로 인해 발생하는 손실을 초과하는 위약금을 청구할 수 없다는 점이 강조되었습니다.
# - 2008년 사례에서는 할인된 금액 등을 공제대상에서 제외하고, 소비자분쟁해결기준에 따라 잔여대금을 환급해야 한다고 결정되었습니다.
#
# 5. **추가 정보**:
# - 제시된 사례집에서는 광고와 실제 서비스의 차이에 대한 구체적인 사례는 확인할 수 없습니다. 그러나 일반적으로 광고와 실제 제공된 서비스가 다를 경우, 이는 계약의 중요한 사항에 대한 불이행으로 간주될 수 있습니다.
#
# 이러한 조언을 바탕으로 계약 해지 및 환급 절차를 진행하시기 바랍니다. 추가적인 법률 자문이 필요하다면 전문 변호사와 상담하는 것도 고려해 보세요.
#
# 📚 참고 문서 목록:
#   1. 문서 출처: C:/mylangchain/langchain_basic/data/콘텐츠분쟁해결_사례.pdf
#      - 내용 미리보기: 2. 이러닝 69 ■ 2-가 한국소비자원 조정결정례2010_온라인교육 서비스 계약 해지에 따른 이용요금 환급 요구【사건개요】신청인은 2009. 11. 27. 피신청인과 1년 동안 금 600,000원에 피신청인이 제공하는 독학사 온라인교육 서비스를 이용하기로 하는 계약을 체결하여 이용하던 중 대학에 합격하여 같은 해 12. 17. 피신청인에게 계약 해지의 의 ...
#   2. 문서 출처: C:/mylangchain/langchain_basic/data/콘텐츠분쟁해결_사례.pdf
#      - 내용 미리보기: 차  례      콘텐츠분쟁조정 법리 연구 제2부 - 타 분쟁조정사례 조사 - 2009_사용하지 못한 게임머니의 환급 요구·····················································2 72008_인터넷 게임 계정 영구이용 제한조치 취소 요구····································2 82) 조정결정 ...
#   3. 문서 출처: C:/mylangchain/langchain_basic/data/콘텐츠분쟁해결_사례.pdf
#      - 내용 미리보기: 3. 기타(웹) 97 ■ 3-나 전자거래분쟁조정위원회 조정전합의 사례2006_무료 광고 후 서비스 이용요금 청구【사건개요】신청인은 한 사이버몰에서 무료 핸드폰 이용권 이벤트에 참여하던 중 핸드폰 번호와 주민번호를 입력하도록 요구받고 이에 응하자 휴대폰으로 요금결제 메시지가 수신되었다. 신청인은 위 문자가 회사측에서 결제하여주는 무료 이용요금으로 생각하였으나 ...
#   4. 문서 출처: C:/mylangchain/langchain_basic/data/콘텐츠분쟁해결_사례.pdf
#      - 내용 미리보기: 2. 이러닝 57 ■ 2-가 한국소비자원 조정결정례2007_인터넷교육서비스 중도해지 요구【사건개요】청구인은 2006. 2. 8. 피청구인이 운영하는 인터넷교육서비스를 청구인의 자녀가 1년간 이용하기로 약정하고 1,740,000원을 지급하였으나 서비스 내용에 불만이 있어 같은 해 5. 3. 계약해지를 요청하고 적정 금액의 환급을 요구하였다. 피청구인은 청구인 ...
#   5. 문서 출처: C:/mylangchain/langchain_basic/data/콘텐츠분쟁해결_사례.pdf
#      - 내용 미리보기: 2. 이러닝 59 ■ 2-가 한국소비자원 조정결정례2008_온라인 통신교육서비스 이용료 환급 요구【사건개요】신청인은 2007. 8. 8. 피신청인과 신청인 자녀(고등학생)가 온라인 통신교육서비스를 1년간 이용하기로 계약하고 이용대금 1,440,000원을 지급하였으나 같은 해 11. 29.부터 동영상강의서비스가 제공되지 않고 있다며 계약해지 및 이용료 환급을 ...

# %%
def classify_dispute_type(query):
    game_keywords = [
        "게임", "아이템", "계정", "캐릭터", "레벨", "길드", "온라인게임",
        "접속", "패치", "서버", "버그", "결제", "인벤토리", "퀘스트",
        "보상", "랭킹", "게임머니", "게임사", "멀티플레이", "클래스",
        "업데이트", "이벤트", "친구", "길드전", "게임내재화"
    ]

    elearning_keywords = [
        "강의", "온라인교육", "이러닝", "수강", "환불", "화상교육",
        "수업", "강사", "학습", "콘텐츠", "교육비", "교재", "출석",
        "시험", "자격증", "학점", "플랫폼", "멤버십", "재수강",
        "과제", "퀴즈", "학습관리", "튜터링", "수강신청"
    ]

    web_keywords = [
        "웹사이트", "무료체험", "자동결제", "구독", "사이트",
        "회원가입", "탈퇴", "요금", "결제", "환불", "광고",
        "서비스", "이용약관", "개인정보", "쿠키", "프로모션",
        "업데이트", "고객센터", "접속장애", "비밀번호", "보안",
        "트래픽", "검색", "알림", "메일", "서버관리"
    ]
    
    query_lower = query.lower()
    
    if any(keyword in query_lower for keyword in game_keywords):
        return "게임"
    elif any(keyword in query_lower for keyword in elearning_keywords):
        return "이러닝"
    elif any(keyword in query_lower for keyword in web_keywords):
        return "웹콘텐츠"
    else:
        return "기타"

# 테스트 질문 리스트
test_questions = [
    "온라인 게임에서 시스템 오류로 아이템이 사라졌는데, 게임회사가 복구를 거부하고 있습니다. 어떻게 해결할 수 있나요?",
    "인터넷 강의를 중도 해지하려고 하는데 과도한 위약금을 요구받고 있습니다. 정당한가요?",
    "무료체험 후 자동으로 유료전환되어 요금이 청구되었습니다. 환불 가능한가요?",
    "미성년자가 부모 동의 없이 게임 아이템을 구매했습니다. 환불받을 수 있는 방법이 있나요?",
    "온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶습니다. 가능한가요?",
    "길드에서 비매너 행위로 강퇴 당했습니다. 다시 복귀 할 수 있을까요?"
]

# 분쟁 유형 출력
for i, question in enumerate(test_questions, 1):
    dispute_type = classify_dispute_type(question)
    print(f"질문 {i}: {question}")
    print(f"분쟁 유형: {dispute_type}")
    print("-" * 40)
# Out:
# 질문 1: 온라인 게임에서 시스템 오류로 아이템이 사라졌는데, 게임회사가 복구를 거부하고 있습니다. 어떻게 해결할 수 있나요?
# 분쟁 유형: 게임
# ----------------------------------------
# 질문 2: 인터넷 강의를 중도 해지하려고 하는데 과도한 위약금을 요구받고 있습니다. 정당한가요?
# 분쟁 유형: 이러닝
# ----------------------------------------
# 질문 3: 무료체험 후 자동으로 유료전환되어 요금이 청구되었습니다. 환불 가능한가요?
# 분쟁 유형: 이러닝
# ----------------------------------------
# 질문 4: 미성년자가 부모 동의 없이 게임 아이템을 구매했습니다. 환불받을 수 있는 방법이 있나요?
# 분쟁 유형: 게임
# ----------------------------------------
# 질문 5: 온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶습니다. 가능한가요?
# 분쟁 유형: 웹콘텐츠
# ----------------------------------------
# 질문 6: 길드에서 비매너 행위로 강퇴 당했습니다. 다시 복귀 할 수 있을까요?
# 분쟁 유형: 게임
# ----------------------------------------
